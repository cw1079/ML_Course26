# %% [markdown]
# <a href="https://colab.research.google.com/github/cw1079/ML_Course26/blob/main/HW2/Assignment_2_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Connor Williams**
#
# ---
#
#
#
#
# **What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets?**
#
# *   Raw Kaggle data comes with some issues that you might not find in pre-packaged datasets. An example would be dealing with missing values in the encryption_used column and also removing unnecessary ID columns like session_id
#
#
# **How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?**
#
# *   I looked at the missing values by checking column null counts which showed the encryption_used column had missing entries. I fixed it by using the most-frequent strategy with SimpleImputer. Also non-informative ID columns were completely removed because they do not provide anything for the analysis
#
#
# **Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing steps.**
#
# *   Scikit-Learn's ColumnTransformer and Pipeline make data preperation more streamline by handling numerical and categorical data separately. They also prevent data leakage by making sure that preprocessing parameters are only learned from the training data used
#
#
# **Based on your correlation matrix and heatmap, which features show the strongest relationships with the target variable (attack_detected), and what operational insights do these relationships reveal?**
#
# *   The correlation heatmap shows that failed_logins has the strongest relationship with attack_detected. According to my graph it was sitting at 0.28. This looks like the intrusions were mainly caused by brute-force attempts.
