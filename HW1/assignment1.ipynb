# %% [markdown]
# <a href="https://colab.research.google.com/github/cw1079/ML_Course26/blob/main/HW1/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hi')
# Out:
# hi

# %% [markdown]
# ##**My first notebook**
#
# * This demonstrates how to create a simple notebook
# * etc
