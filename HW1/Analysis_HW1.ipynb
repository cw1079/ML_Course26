# %% [markdown]
# ### Question 1: Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
# * Key steps include creating a github repository and then organzing folders for each assignment you have. After creating the workbook, you can submit work by doing File -> Save a copy in github which then prompts you to choose repository. You are then able to choose a subfolder by adding the folder name first (Example: HW1:assignment1.ipynb). Finally you add a commit message and click ok to push the file to the repository.
#
# ### Question 2: Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
# * Every file within Module 0 ran perfectly and I have did not need to adjust anything. I learned that with using notebook, you must run the code starting with the libraries or else you will get errors with every line that you try to run.
#
# ### Question 3: Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
# * I created my repository on github followed by creating the different homework folders. Afterwards, I downloaded all 5 notebooks and ran them to ensure there were no errors. Once that was done, I copied them to my github repo and added HW1/ before the notebook name to make sure it goes to the correct homework folder. Finally, I moved everything to VS code by cloning the repository so I can edit and push the changes made to the notebook. VS code in my opinion is much easier than the web because it is way more versatile and will be better to use in the long run when having a lot of assignments.
# hows this
#
#
# ### Question 4: Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
# * Establishing a strong command of python is important because a large part of maching learning is based on manipulating data before feeding it into a model. The machine learning libraries depend on data structures like lists and loops so if you are struggling with these concepts, you can become overwhelmed and it will be harder to understand the machine learning algorithms in this course
